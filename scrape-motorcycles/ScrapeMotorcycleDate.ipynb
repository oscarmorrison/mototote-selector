# %%
import requests
from bs4 import BeautifulSoup
import re
import json

# %%
# URL of the webpage to scrape
url = 'https://bikez.com/years/index.php'

# Fetch the page content
response = requests.get(url)
html_output = response.content

# %%
# Parse the content using BeautifulSoup
soup = BeautifulSoup(page_content, 'html.parser')

# %%
years_links = []
for year_link in soup.find_all('a'):
    text = year_link.get_text()
    if text.isdigit():  # Only get the years
        link = year_link.get('href')  # Extract the link
        years_links.append((text, link))

print("Years and links listed on the webpage:")
for year, link in years_links:
    print(f"Year: {year}, Link: {link}")
# Out:
# Years and links listed on the webpage:
# Year: 2025, Link: ../year/2025-motorcycle-models.php
# Year: 2024, Link: ../year/2024-motorcycle-models.php
# Year: 2023, Link: ../year/2023-motorcycle-models.php
# Year: 2022, Link: ../year/2022-motorcycle-models.php
# Year: 2021, Link: ../year/2021-motorcycle-models.php
# Year: 2020, Link: ../year/2020-motorcycle-models.php
# Year: 2019, Link: ../year/2019-motorcycle-models.php
# Year: 2018, Link: ../year/2018-motorcycle-models.php
# Year: 2017, Link: ../year/2017-motorcycle-models.php
# Year: 2016, Link: ../year/2016-motorcycle-models.php
# Year: 2015, Link: ../year/2015-motorcycle-models.php
# Year: 2014, Link: ../year/2014-motorcycle-models.php
# Year: 2013, Link: ../year/2013-motorcycle-models.php
# Year: 2012, Link: ../year/2012-motorcycle-models.php
# Year: 2011, Link: ../year/2011-motorcycle-models.php
# Year: 2010, Link: ../year/2010-motorcycle-models.php
# Year: 2009, Link: ../year/2009-motorcycle-models.php
# ...

# %%
EXAMPLE_YEAR_URL='https://bikez.com/year/2008-motorcycle-models.php'

# %%
response = requests.get(EXAMPLE_YEAR_URL)
year_page_output = response.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response = requests.get(EXAMPLE_YEAR_URL)
#       2 year_page_output = response.content
#
# NameError: name 'requests' is not defined

# %%
soup = BeautifulSoup(year_page_output, 'html.parser')
table = soup.find('table', {'class': 'zebra'})

# Extract model names and corresponding links
models = []
if table:
    for row in table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) > 0:
            model_link = cols[0].find('a')
            if model_link:
                model_name = model_link.get_text()
                model_url = model_link.get('href')
                models.append((model_name, model_url))

# Output the results
print("Model names and their links:")
for model, link in models:
    print(f"Model: {model}, Link: {link}")
# Out:
# Model names and their links:
# Model: Adiva AD125, Link: ../motorcycles/adiva_ad125_2008.php
# Model: Adiva AD250, Link: ../motorcycles/adiva_ad250_2008.php
# Model: Adly Cat 100, Link: ../motorcycles/adly_cat_100_2008.php
# Model: Adly Cat 125 B, Link: ../motorcycles/adly_cat_125_b_2008.php
# Model: Adly Cat 125 D, Link: ../motorcycles/adly_cat_125_d_2008.php
# Model: Adly Cat 125 S, Link: ../motorcycles/adly_cat_125_s_2008.php
# Model: Adly Cat 50, Link: ../motorcycles/adly_cat_50_2008.php
# Model: Adly Jet 100, Link: ../motorcycles/adly_jet_100_2008.php
# Model: Adly Jet 50, Link: ../motorcycles/adly_jet_50_2008.php
# Model: Adly Noble 100, Link: ../motorcycles/adly_noble_100_2008.php
# Model: Adly, Link: ../models/adly_models.php
# Model: Adly Noble 50, Link: ../motorcycles/adly_noble_50_2008.php
# Model: Adly, Link: ../models/adly_models.php
# Model: Adly Panther 100, Link: ../motorcycles/adly_panther_100_2008.php
# Model: Adly, Link: ../models/adly_models.php
# ...

# %%
url = 'https://bikez.com/motorcycles/aprilia_sportcity_200_2008.php'
response = requests.get(url)
bike_page_output = response.content

# %%
bike_page_output
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <!--meta http-equiv="X-UA-Compatible" content="IE=edge" -->\r\n    <meta name="viewport" content="width=device-width">\r\n\r\n    <link rel="preconnect" href="https://googleads.g.doubleclick.net"  crossorigin>\r\n    <link rel="preconnect" href="https://d.pub.network"  crossorigin>\r\n    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\r\n        <link rel="preconnect" href="https://www.googletagmanager.com" crossorigin>\r\n\r\n    <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\r\n    <script>\r\n          (function() {\r\n              var host = window.location.hostname;\r\n              var element = document.createElement(\'script\');\r\n              var firstScript = document.getElementsByTagName(\'script\')[0];\r\n              var url = \'https://cmp.quantcast.com\'\r\n                  .concat(\'/choice/\', \'paKtYzR9-WCTC\', \'/\', host, \'/choice.j
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL of the webpage to scrape
url = 'https://bikez.com/years/index.php'

# Fetch the page content
response = requests.get(url)
html_output = response.content

# %%
# Parse the content using BeautifulSoup
soup = BeautifulSoup(page_content, 'html.parser')

# %%
years_links = []
for year_link in soup.find_all('a'):
    text = year_link.get_text()
    if text.isdigit():  # Only get the years
        link = year_link.get('href')  # Extract the link
        years_links.append((text, link))

print("Years and links listed on the webpage:")
for year, link in years_links:
    print(f"Year: {year}, Link: {link}")
# Out:
# Years and links listed on the webpage:
# Year: 2025, Link: ../year/2025-motorcycle-models.php
# Year: 2024, Link: ../year/2024-motorcycle-models.php
# Year: 2023, Link: ../year/2023-motorcycle-models.php
# Year: 2022, Link: ../year/2022-motorcycle-models.php
# Year: 2021, Link: ../year/2021-motorcycle-models.php
# Year: 2020, Link: ../year/2020-motorcycle-models.php
# Year: 2019, Link: ../year/2019-motorcycle-models.php
# Year: 2018, Link: ../year/2018-motorcycle-models.php
# Year: 2017, Link: ../year/2017-motorcycle-models.php
# Year: 2016, Link: ../year/2016-motorcycle-models.php
# Year: 2015, Link: ../year/2015-motorcycle-models.php
# Year: 2014, Link: ../year/2014-motorcycle-models.php
# Year: 2013, Link: ../year/2013-motorcycle-models.php
# Year: 2012, Link: ../year/2012-motorcycle-models.php
# Year: 2011, Link: ../year/2011-motorcycle-models.php
# Year: 2010, Link: ../year/2010-motorcycle-models.php
# Year: 2009, Link: ../year/2009-motorcycle-models.php
# ...

# %%
EXAMPLE_YEAR_URL='https://bikez.com/year/2016-motorcycle-models.php'

# %%
response = requests.get(EXAMPLE_YEAR_URL)
year_page_output = response.content

# %%
soup = BeautifulSoup(year_page_output, 'html.parser')
table = soup.find('table', {'class': 'zebra'})

# Extract model names and corresponding links
models = []
if table:
    for row in table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) > 0:
            model_link = cols[0].find('a')
            if model_link:
                model_name = model_link.get_text()
                model_url = model_link.get('href')
                models.append((model_name, model_url))

# Output the results
print("Model names and their links:")
for model, link in models:
    print(f"Model: {model}, Link: {link}")
# Out:
# Model names and their links:
# Model: Access AMS 3.20 SuperCross, Link: ../motorcycles/access_ams_320_supercross_2016.php
# Model: Access AMS 4.30 SuperMoto EFI, Link: ../motorcycles/access_ams_430_supermoto_efi_2016.php
# Model: Access AMS 4.38 SM Gear Shift, Link: ../motorcycles/access_ams_438_sm_gear_shift_2016.php
# Model: Access AMS 4.38 SX Gear Shift, Link: ../motorcycles/access_ams_438_sx_gear_shift_2016.php
# Model: Access AMS 6.46 Basic, Link: ../motorcycles/access_ams_646_basic_2016.php
# Model: Access AMS 6.46 Lux, Link: ../motorcycles/access_ams_646_lux_2016.php
# Model: Access AMS 6.46 Lux Long, Link: ../motorcycles/access_ams_646_lux_long_2016.php
# Model: Access AMS 8.57 Lux LV, Link: ../motorcycles/access_ams_857_lux_lv_2016.php
# Model: AJS Bobber 125, Link: ../motorcycles/ajs_bobber_125_2016.php
# Model: AJS Daytona 125, Link: ../motorcycles/ajs_daytona_125_2016.php
# Model: AJS, Link: ../models/ajs_models.php
# ...

# %%
# url = 'https://bikez.com/motorcycles/yamaha_fjr1300a_2008.php'
# url = 'https://bikez.com/motorcycles/zongshen_storm_v250_2008.php'
url = 'https://bikez.com/motorcycles/ducati_diavel_carbon_2016.php'
response = requests.get(url)
bike_page_output = response.content

# %%
soup = BeautifulSoup(bike_page_output, 'html.parser')

# %%
general = soup.find(id="GENERAL")
table = general.find_parent('table')
bike_data = {}

for row in table.find_all('tr'):
    th = row.find('th')
    if th:
        # If a section header is found, update the current section
        section = th.get_text(strip=True)
        bike_data[section] = {}
    else:
        # Extract the specification name and value
        cols = row.find_all('td')
        if len(cols) == 2:
            key = cols[0].get_text(strip=True).replace(":", "")
            value = cols[1].get_text(strip=True)
            bike_data[section][key] = value

json.dumps(bike_data)
# Out:
# '{"General information": {"Model": "Ducati Diavel Carbon", "Year of manufacture": "2016", "Type": "Naked bike", "Rating": "Do you know this bike?Click here to rate it. We miss 1 vote to show the rating."}, "Engine and transmission": {"Engine size": "1198.4 ccm (73.13 cubic inches)", "Type of engine": "V2, four-stroke", "Engine details": "Testastretta 11\\u00b0 L-Twin", "Output": "162.0HP(118.2kW)) @ 9250RPM", "Torque": "130.5 Nm (13.3 kgf-m or 96.3 ft.lbs) @ 8000RPM", "Compression": "12.5:1", "Borexstroke": "106.0 x 67.9 mm (4.2 x 2.7 inches)", "Valvesper cylinder": "4", "Fuel system": "Injection. Elliptical throttle bodies, fully ride-by-wire controlled", "Fuel control": "Desmodromic valve control", "Cooling system": "Liquid", "Gearbox": "6-speed", "Transmission type": "Chain  (final drive)", "Clutch": "Slipper and self-servo wet multiplate clutch with hydraulic control", "Driveline": "Front sprocket 15; Rear sprocket 43. Primary drive: Straight cut gears, ratio 1.84.", "Emission de
# ...

# %%
brands_url = "https://bikez.com/brands/index.php"
brands_response = requests.get(url)
brands_content = brands_response.content
brands_soup = BeautifulSoup(brands_content, 'html.parser')

# %%
brand_select = brands_soup.find('select', {'id': 'CompBrand'})
brands = []
for option in brand_select.find_all('option'):
    brand_name = option.text.strip()   # Get the text inside the option tag
    brands.append((brand_name))
brands = sorted(brands, key=len, reverse=True)

# %%
sorted(brands)
# Out:
# ['AJP',
#  'AJS',
#  'APC',
#  'ATK',
#  'Acabion',
#  'Access',
#  'Ace',
#  'Adiva',
#  'Adler',
#  'Adly',
#  'Aeon',
#  'Aermacchi',
#  'Agrati',
#  'Alfer',
#  'Alligator',
#  'Allstate',
#  'AlphaSports',
#  'Alta',
#  'Amazonas',
#  'American Eagle',
#  'American IronHorse',
#  'Apollino',
#  'Apollo',
#  'Aprilia',
#  'Apsonic',
#  'Arch',
#  'Archive',
#  'Arctic Cat',
#  'Ardie',
#  'Ariel',
#  'Arlen Ness',
#  'Arqin',
#  'Askoll',
#  'Aspes',
#  'Ather',
#  'Atlas Honda',
#  'Aurora',
#  'Avanturaa Choppers',
#  'Avinton',
#  'Avon',
#  'Azel',
#  'BMC Choppers',
#  'BMW',
#  'BPG',
#  'BPG Werks',
#  'BSA',
#  'BSA Motors',
#  'Bajaj',
#  'Balkan',
#  'Baltmotors',
#  'BamX',
#  'Baotian',
#  'Barossa',
#  'Batavus',
#  'Beeline',
#  'Benda',
#  'Benelli',
#  'Bennche',
#  'Beta',
#  'Better',
#  'Big Bear Choppers',
#  'Big Dog',
#  'Bimota',
#  'Bintelli',
#  'Black Douglas',
#  'Blackburne',
#  'Blata',
#  'Bluroc',
#  'Boom Trikes',
#  'Borile',
#  'Boss Hoss',
# ...

# %%
def split_make_and_model(model_name, brands):
    # Sort brands by length (longest first) to match multi-word brands first
    original_model_name = model_name  # Preserve the original case
    model_name = model_name.lower()  # Convert to lowercase for case-insensitive comparison

    # Check if any brand is in the model name (case-insensitive)
    for brand in brands:
        brand_lower = brand.lower()  # Convert brand to lowercase for comparison
        if brand_lower in model_name:
            # If found, split at the brand in the original case-sensitive model name
            model = original_model_name.replace(brand, '').strip()  # Preserve original case for the result
            return brand, model

    # If no brand is found, return the original model name with None as make
    return None, original_model_name

# %%
bike_data
# Out:
# {'General information': {'Model': 'Ducati Diavel Carbon',
#   'Year of manufacture': '2016',
#   'Type': 'Naked bike',
#   'Rating': 'Do you know this bike?Click here to rate it. We miss 1 vote to show the rating.'},
#  'Engine and transmission': {'Engine size': '1198.4 ccm (73.13 cubic inches)',
#   'Type of engine': 'V2, four-stroke',
#   'Engine details': 'Testastretta 11° L-Twin',
#   'Output': '162.0HP(118.2kW)) @ 9250RPM',
#   'Torque': '130.5 Nm (13.3 kgf-m or 96.3 ft.lbs) @ 8000RPM',
#   'Compression': '12.5:1',
#   'Borexstroke': '106.0 x 67.9 mm (4.2 x 2.7 inches)',
#   'Valvesper cylinder': '4',
#   'Fuel system': 'Injection. Elliptical throttle bodies, fully ride-by-wire controlled',
#   'Fuel control': 'Desmodromic valve control',
#   'Cooling system': 'Liquid',
#   'Gearbox': '6-speed',
#   'Transmission type': 'Chain  (final drive)',
#   'Clutch': 'Slipper and self-servo wet multiplate clutch with hydraulic control',
# ...

# %%
bike_model_text = next((bike_data['General information'][key] for key in ['Model name', 'Model','Motorcycle name']
                   if key in bike_data['General information']), None)

# %%
bike_model_text
# Out:
# 'Ducati Diavel Carbon'

# %%
[make, model] = split_make_and_model(bike_model_text, brands)

# %%
cleaned_data = {}
cleaned_data['make'] = make
cleaned_data['model'] = model
cleaned_data['type'] = cleaned_data['year'] = next((bike_data['General information'][key] for key in ['Type']
                   if key in bike_data['General information']), None)
cleaned_data['year'] = next((bike_data['General information'][key] for key in ['Year model', 'Year','Year of manufacture']
                   if key in bike_data['General information']), None)
cleaned_data['wheelbase'] = bike_data['Physical measures and capacities']['Wheelbase']
cleaned_data['frontyre'] = bike_data['Chassis, suspension, brakes and wheels']['Front tire']
cleaned_data['reartyre'] = bike_data['Chassis, suspension, brakes and wheels']['Rear tire']

print(cleaned_data)
# Out:
# {'make': 'Ducati', 'model': 'Diavel Carbon', 'type': 'Naked bike', 'year': '2016', 'wheelbase': '1590 mm (62.6 inches)', 'frontyre': '120/70-ZR17', 'reartyre': '240/45-ZR17'}
